# %%
from sklearn import datasets
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage  
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from scipy.cluster.hierarchy import linkage, fcluster
from mpl_toolkits.mplot3d import Axes3D

# %%
awareness = ( 0.54 , 0.41 , 0.73 )
clarity = ( 2.19 , 2.01 , 2.05 )
adaptability = ( -0.31 , -0.31 , -0.23 )
relationship = ( 0.27 , 0.53 , 0.91 )
communication = ( 6.81 , 6.53 , 6.86 )
ghostwrite = ( 0.33 , 0.48 , 0.36 )
branding = ( 1.62 , 1.57 , 1.54 )
fear = ( 0.14 , -0.01 , 0.03 )
softskill = ( 2.81 , 3.61 , 3.34 )
intelligence = ( 0.28 , 0.47 , 0.83 )
action = ( -0.43 , -0.48 , -0.41 )
positivity = ( 1.38 , 1.4 , 1.42 )
alignment = ( 0.08 , 0.04 , -0.02 )
boundary = ( -0.22 , -0.15 , -0.34 )
trust = ( 0.34 , 0.35 , 0.27 )
progress = ( 4.37 , 3.78 , 3.83 )
growth = ( 1.95 , 2.39 , 2.67 )
email = ( -0.42 , -0.45 , -0.5 )
business = ( 0.45 , 0.86 , 1.19 )
write = ( 0.45 , 0.31 , 0.24 )
productivity = ( 0.57 , 0.55 , 0.33 )
hire = ( -0.51 , -0.47 , -0.49 )
team = ( -0.51 , -0.47 , -0.49 )
community = ( -0.29 , -0.29 , -0.13 )
change = ( 0.78 , 0.61 , 0.96 )
goals = ( 1.51 , 1.52 , 1.31 )
success = ( 1.96 , 2.12 , 2.71 )
development = ( 0.04 , 0.33 , 0.59 )
brand = ( -0.58 , -0.57 , -0.49 )
content = ( 3.26 , 3.05 , 1.83 )
wellbeing = ( -0.41 , -0.37 , -0.42 )
creativity = ( 0.5 , 0.28 , 0.44 )
humanbehavior = ( -0.58 , -0.56 , -0.57 )
intention = ( 0.33 , 0.18 , 0.28 )
attention = ( 0.04 , -0.01 , -0.06 )
consistency = ( -0.44 , -0.45 , -0.42 )
discipline = ( -0.44 , -0.45 , -0.42 )
wisdom = ( -0.15 , -0.08 , -0.07 )
video = ( 0.62 , 0.88 , 0.31 )
resilience = ( -0.52 , -0.55 , -0.54 )
empathy = ( 0.69 , 0.78 , 0.61 )
kindness = ( -0.02 , -0.01 , -0.16 )
hope = ( -0.52 , -0.55 , -0.54 )
optimism = ( -0.52 , -0.55 , -0.54 )
possibility = ( -0.46 , -0.5 , -0.47 )
focus = ( 0.17 , 0.1 , 0.03 )
grit = ( -0.49 , -0.46 , -0.44 )
growthmindset = ( -0.21 , -0.11 , 0.1 )
help = ( -0.45 , -0.47 , -0.51 )
vulnerability = ( -0.32 , -0.25 , -0.28 )
promise = ( -0.51 , -0.51 , -0.54 )
happyholiday = ( -0.42 , -0.21 , -0.35 )
presence = ( -0.52 , -0.44 , -0.52 )
choice = ( -0.46 , -0.48 , -0.49 )
collaboration = ( -0.31 , -0.28 , -0.36 )
curiosity = ( -0.42 , -0.42 , -0.42 )
listen = ( -0.08 , -0.09 , -0.19 )
perspective = ( 0.84 , 0.7 , 0.71 )
position = ( 0.32 , 0.32 , 0.22 )
respect = ( -0.49 , -0.46 , -0.54 )
curious = ( -0.54 , -0.54 , -0.55 )
humility = ( -0.43 , -0.43 , -0.39 )
gratitude = ( 0.32 , 0.45 , 0.4 )
competence = ( -0.49 , -0.5 , -0.51 )
confidence = ( -0.49 , -0.5 , -0.51 )
candor = ( -0.49 , -0.5 , -0.51 )
veteransday = ( -0.53 , -0.55 , -0.52 )
veteran = ( -0.53 , -0.55 , -0.52 )
uncertainty = ( -0.52 , -0.53 , -0.55 )
positive = ( -0.55 , -0.56 , -0.55 )
influence = ( -0.48 , -0.47 , -0.52 )
passion = ( -0.59 , -0.58 , -0.58 )
podcast = ( -0.42 , -0.45 , -0.44 )
post = ( -0.59 , -0.58 , -0.58 )
hindsight = ( -0.51 , -0.53 , -0.49 )
foresight = ( -0.51 , -0.53 , -0.49 )
transformation = ( -0.08 , -0.15 , 0.13 )
inspiration = ( -0.23 , -0.24 , -0.35 )
mindset = ( 1.68 , 1.79 , 2.54 )
impact = ( -0.1 , -0.16 , -0.41 )
encouragement = ( -0.46 , -0.48 , -0.54 )
perfection = ( -0.52 , -0.53 , -0.49 )
time = ( -0.4 , -0.33 , -0.48 )
visualization = ( -0.54 , -0.56 , -0.56 )
work = ( -0.12 , -0.14 , -0.14 )
burnout = ( -0.42 , -0.39 , -0.41 )
stress = ( -0.55 , -0.57 , -0.55 )
softskill = ( -0.59 , -0.59 , -0.57 )
balance = ( -0.54 , -0.56 , -0.54 )
read = ( -0.58 , -0.59 , -0.56 )
write = ( -0.58 , -0.59 , -0.56 )
fiction = ( -0.58 , -0.59 , -0.56 )
human = ( -0.56 , -0.54 , -0.57 )
advice = ( 0.5 , 0.53 , 0.09 )
idea = ( -0.52 , -0.52 , -0.55 )
purpose = ( -0.33 , -0.32 , -0.32 )
talent = ( 0.13 , 0.03 , -0.2 )
energy = ( -0.16 , -0.26 , -0.21 )
guilt = ( -0.22 , -0.31 , -0.29 )
coronavirus = ( 1.73 , 1.4 , 1.46 )
lift = ( -0.56 , -0.54 , -0.52 )
mentalhealth = ( -0.46 , -0.43 , -0.41 )
simplicity = ( -0.09 , -0.15 , -0.32 )
badass = ( -0.45 , -0.5 , -0.52 )
understand = ( -0.4 , -0.45 , -0.49 )
unity = ( -0.4 , -0.45 , -0.49 )
humanity = ( -0.45 , -0.49 , -0.54 )
brand = ( -0.41 , -0.35 , -0.41 )
constraint = ( -0.38 , -0.45 , -0.38 )
reinvention = ( -0.38 , -0.43 , -0.38 )
motivation = ( -0.43 , -0.47 , -0.49 )
reframe = ( -0.04 , -0.17 , -0.27 )
gift = ( -0.23 , -0.31 , -0.49 )
support = ( -0.53 , -0.52 , -0.49 )
innovation = ( -0.28 , -0.42 , -0.32 )
performance = ( -0.41 , -0.43 , -0.49 )
business = ( -0.52 , -0.55 , -0.52 )
reflection = ( -0.31 , -0.36 , -0.38 )
meditation = ( -0.41 , -0.45 , -0.49 )
business = ( -0.48 , -0.46 , -0.44 )
charisma = ( -0.04 , -0.12 , -0.1 )
comparison = ( -0.44 , -0.45 , -0.49 )
unstuck = ( -0.42 , -0.48 , -0.38 )
future = ( -0.42 , -0.46 , -0.42 )
hr = ( -0.53 , -0.53 , -0.54 )
experience = ( -0.53 , -0.53 , -0.54 )
advisory = ( -0.42 , -0.37 , -0.44 )
consult = ( -0.42 , -0.37 , -0.44 )
generosity = ( -0.47 , -0.5 , -0.38 )
newyear = ( -0.47 , -0.5 , -0.44 )
resolution = ( -0.45 , -0.46 , -0.44 )
appreciation = ( -0.36 , -0.38 , -0.02 )
transition = ( -0.53 , -0.53 , -0.52 )
liminality = ( -0.4 , -0.34 , -0.27 )
duality = ( -0.53 , -0.55 , -0.49 )
accountability = ( -0.4 , -0.36 , -0.38 )
travel = ( -0.59 , -0.56 , -0.49 )
culture = ( -0.51 , -0.49 , -0.49 )
vacation = ( -0.58 , -0.58 , -0.54 )
holiday = ( -0.58 , -0.58 , -0.54 )
sales = ( -0.45 , -0.42 , -0.36 )
intellgence = ( -0.56 , -0.57 , -0.52 )
service = ( -0.56 , -0.58 , -0.57 )
value = ( -0.53 , -0.55 , -0.52 )
perceptive = ( -0.53 , -0.49 , -0.44 )
communicate = ( -0.59 , -0.59 , -0.58 )
readinglist = ( -0.54 , -0.55 , -0.52 )
serve = ( -0.57 , -0.58 , -0.56 )
human = ( -0.17 , 0.07 , 0.18 )
ai = ( -0.58 , -0.58 , -0.55 )
teamwork = ( -0.56 , -0.54 , -0.5 )
open = ( -0.58 , -0.57 , -0.58 )
persuasion = ( -0.6 , -0.6 , -0.58 )
virtual = ( -0.44 , -0.45 , -0.27 )
career = ( 2.74 , 2.8 , 2.77 )
entrepreneur = ( -0.09 , -0.14 , 0.2 )
leadership = ( 2.42 , 2.55 , 2.71 )
illuminate = ( 1.46 , 1.33 , 1.15 )
linkedin = ( 1.16 , 1.38 , 1.05 )
self = ( 0.95 , 1.08 , 0.65 )
book = ( -0.35 , -0.39 , -0.28 )
connect = ( 2.75 , 2.56 , 2.59 )
manage = ( 0.77 , 0.69 , 0.61 )
story = ( 0.68 , 0.88 , 0.68 )
social = ( 2.75 , 3.03 , 2.35 )
education = ( 0.2 , -0.24 , 2.4 )
internation = ( 0.2 , -0.24 , 2.4 )
writer = ( 0.2 , -0.24 , 2.4 )
school = ( 0.2 , -0.24 , 3.2 )
education = ( 0.0 , -0.25 , 0.8 )
career = ( 0.0 , -0.25 , 0.8 )
collaboration = ( 0.0 , -0.25 , 0.8 )
college = ( 0.2 , -0.21 , 0.6 )
trauma = ( 0.2 , -0.21 , 0.6 )
children = ( 0.2 , -0.21 , 0.6 )
media = ( 10.8 , 0.49 , 50.2 )
study = ( 0.2 , -0.25 , 3.6 )
communication = ( 0.2 , -0.25 , 3.6 )
liberal = ( 0.2 , -0.25 , 3.6 )
professor = ( 0.2 , -0.25 , 3.6 )
hr = ( 7.0 , -0.23 , 33.6 )
leader = ( 7.0 , -0.23 , 33.6 )
innovation = ( 7.0 , -0.23 , 33.6 )
lobby = ( 7.0 , -0.23 , 33.6 )
content = ( 1.2 , 0.24 , 12.8 )
female = ( 1.2 , -0.07 , 9.2 )
founder = ( 1.2 , -0.02 , 9.2 )
create = ( 1.2 , -0.07 , 9.2 )
transport = ( 0.0 , -0.25 , 0.6 )
heavy = ( 0.0 , -0.25 , 0.6 )
experience = ( 0.0 , -0.25 , 0.6 )
operational = ( 0.0 , -0.25 , 0.6 )
specialist = ( 0.0 , -0.25 , 0.6 )
market = ( 83.8 , 6.82 , 461.2 )
communication = ( 1.4 , 0.09 , 14.0 )
across = ( 0.0 , -0.24 , 0.4 )
specialize = ( 0.0 , -0.24 , 0.4 )
b2b = ( 0.4 , -0.2 , 1.8 )
product = ( 0.0 , -0.02 , 10.4 )
linkedin = ( 2.6 , 0.14 , 51.8 )
technology = ( 1.4 , 0.21 , 34.0 )
management = ( 0.0 , 0.04 , 15.2 )
develop = ( 0.6 , -0.19 , 12.2 )
new = ( 19.4 , -0.16 , 115.4 )
health = ( 0.8 , 0.19 , 15.4 )
clinical = ( 0.6 , -0.19 , 12.2 )
care = ( 0.8 , -0.15 , 12.8 )
specialty = ( 0.0 , -0.25 , 0.6 )
healthcare = ( 0.4 , -0.2 , 4.8 )
technology = ( 0.0 , -0.25 , 0.6 )
top = ( 81.6 , 6.51 , 440.6 )
phd = ( 0.2 , -0.13 , 0.6 )
care = ( 0.2 , -0.21 , 0.6 )
beth = ( 0.0 , -0.24 , 20.4 )
biotech = ( 0.0 , -0.24 , 20.4 )
entrepreneur = ( 0.2 , -0.24 , 24.2 )
venture = ( 0.0 , -0.24 , 20.4 )
business = ( 82.8 , 7.06 , 457.4 )
entrepreneur = ( 0.2 , -0.24 , 3.6 )
help = ( 1.2 , -0.21 , 10.6 )
good = ( 0.0 , -0.11 , 0.2 )
life = ( 0.0 , -0.11 , 0.2 )
mosquito = ( 0.0 , -0.11 , 0.2 )
party = ( 0.0 , -0.11 , 0.2 )
want = ( 0.0 , -0.11 , 0.2 )
emotional = ( 1.0 , -0.15 , 2.0 )
intelligence = ( 1.0 , -0.15 , 2.0 )
example = ( 1.0 , -0.15 , 2.0 )
work = ( 3.8 , 0.53 , 18.0 )
write = ( 1.0 , -0.15 , 2.0 )
world = ( 0.6 , 0.12 , 4.0 )
year = ( 0.6 , 0.12 , 4.0 )
burnout = ( 0.6 , 0.12 , 4.0 )
client = ( 7.6 , -0.2 , 20.0 )
swordfish = ( 0.0 , -0.23 , 0.0 )
service = ( 0.0 , -0.23 , 0.0 )
creative = ( 2.2 , -0.25 , 9.4 )
director = ( 2.2 , -0.25 , 9.4 )
social = ( 0.4 , 0.01 , 5.2 )
gap = ( 0.0 , -0.09 , 0.2 )
operation = ( 0.0 , -0.09 , 0.2 )
name = ( 0.0 , -0.19 , 3.6 )
say = ( 1.0 , -0.21 , 7.0 )
people = ( 1.0 , -0.18 , 7.2 )
word = ( 1.0 , -0.21 , 7.0 )
thing = ( 2.8 , 0.07 , 15.6 )
best = ( 2.8 , 0.07 , 15.6 )
way = ( 2.8 , 0.07 , 15.6 )
know = ( 2.8 , 0.11 , 16.4 )
thank = ( 0.4 , -0.2 , 1.4 )
brand = ( 93.2 , 6.46 , 495.4 )
digital = ( 0.0 , 0.03 , 0.0 )
week = ( 2.2 , 0.31 , 24.2 )
executive = ( 0.2 , -0.24 , 2.8 )
track = ( 0.2 , -0.24 , 2.8 )
record = ( 0.2 , -0.24 , 2.8 )
base = ( 0.2 , -0.1 , 0.6 )
get = ( 0.0 , -0.24 , 1.4 )
author = ( 0.0 , -0.24 , 1.4 )
valley = ( 0.2 , -0.24 , 0.8 )
company = ( 12.0 , -0.21 , 54.0 )
time = ( 14.0 , -0.24 , 17.0 )
silicon = ( 0.2 , -0.24 , 0.8 )
university = ( 0.4 , -0.21 , 9.0 )
talent = ( 0.0 , -0.25 , 2.0 )
kaizen = ( 0.0 , -0.25 , 2.0 )
search = ( 0.0 , -0.25 , 2.0 )
leadership = ( 7.6 , -0.22 , 22.0 )
vikram = ( 0.0 , -0.21 , 0.2 )
like = ( 0.0 , -0.0 , 1.6 )
fintech = ( 0.0 , -0.0 , 1.6 )
series = ( 0.0 , -0.0 , 1.6 )
economy = ( 13.8 , -0.24 , 16.2 )
reporter = ( 13.8 , -0.24 , 16.2 )
bank = ( 0.0 , -0.02 , 5.4 )
india = ( 0.4 , 0.11 , 13.4 )
finance = ( 0.4 , 0.11 , 13.4 )
standard = ( 0.0 , -0.02 , 5.4 )
platform = ( 0.8 , -0.17 , 4.8 )
industry = ( 0.8 , -0.17 , 4.8 )
mobile = ( 0.8 , -0.12 , 4.8 )
design = ( 0.8 , -0.17 , 4.8 )
software = ( 2.2 , -0.16 , 36.2 )
jody = ( 0.0 , 0.05 , 0.0 )
account = ( 0.2 , 0.06 , 1.4 )
firm = ( 0.0 , 0.05 , 0.0 )
finance = ( 0.0 , 0.05 , 0.0 )
consult = ( 0.4 , -0.12 , 8.0 )
wealth = ( 0.4 , -0.12 , 8.0 )
investment = ( 0.4 , -0.12 , 8.0 )
engineer = ( 1.4 , -0.24 , 31.4 )
build = ( 1.4 , -0.24 , 31.4 )
every = ( 1.4 , -0.24 , 31.4 )
day = ( 1.4 , -0.24 , 31.4 )
role = ( 0.2 , -0.24 , 1.4 )
manager = ( 0.2 , -0.24 , 1.4 )
psychology = ( 1.0 , -0.11 , 7.0 )
acquire = ( 1.0 , -0.11 , 7.0 )
nir = ( 1.0 , -0.11 , 7.0 )
eyal = ( 1.0 , -0.11 , 7.0 )
palmer = ( 0.0 , -0.06 , 0.0 )
special = ( 0.0 , -0.06 , 0.0 )
lee = ( 1.2 , -0.24 , 23.8 )
africa = ( 1.2 , -0.24 , 23.8 )
naik = ( 1.2 , -0.24 , 23.8 )
innovator = ( 0.0 , -0.2 , 0.0 )
interview = ( 0.0 , -0.2 , 0.0 )
city = ( 5.0 , -0.23 , 66.4 )
move = ( 5.0 , -0.23 , 66.4 )
women = ( 0.4 , -0.24 , 12.4 )
citylife = ( 0.0 , -0.25 , 0.2 )
government = ( 0.0 , -0.25 , 0.2 )
juliet = ( 0.0 , -0.24 , 1.6 )
mutual = ( 0.0 , -0.24 , 1.6 )
year = ( 0.0 , -0.24 , 1.6 )
kleiner = ( 0.0 , -0.24 , 1.6 )
sogal = ( 0.4 , -0.24 , 12.2 )
magazine = ( 0.4 , -0.24 , 12.2 )
pocket = ( 0.4 , -0.24 , 12.2 )
trust = ( 6.6 , -0.23 , 4.2 )
professional = ( 6.6 , -0.23 , 4.2 )
volk = ( 6.6 , -0.23 , 4.2 )
follow = ( 6.6 , -0.23 , 4.2 )
newsletter = ( 6.6 , -0.23 , 4.2 )
personal = ( 19.2 , -0.19 , 71.8 )
podcast = ( 11.6 , -0.22 , 51.8 )
video = ( 11.6 , -0.22 , 51.8 )
ad = ( 0.8 , -0.24 , 9.0 )
expensive = ( 0.8 , -0.24 , 9.0 )
think = ( 7.6 , -0.22 , 20.0 )
Group = ( 1.0 , -0.7 , 12.0 )
School = ( 0.0 , -0.72 , 4.0 )
University = ( 0.0 , -0.72 , 4.0 )
Counsel = ( 1.0 , -0.38 , 3.0 )
University = ( 1.0 , -0.71 , 18.0 )
App = ( 35.0 , -0.62 , 168.0 )
Startup = ( 6.0 , 0.84 , 46.0 )
technology = ( 0.0 , -0.71 , 2.0 )
Read = ( 0.0 , -0.71 , 2.0 )
LinkedIn = ( 0.0 , -0.71 , 2.0 )
technology = ( 0.0 , -0.71 , 2.0 )
news = ( 0.0 , -0.71 , 2.0 )
Consulting = ( 3.0 , -0.24 , 61.0 )
Healthcare = ( 0.0 , -0.72 , 1.0 )
Biodesign = ( 0.0 , -0.71 , 3.0 )
Medical = ( 1.0 , 0.29 , 3.0 )
Partners = ( 0.0 , -0.7 , 102.0 )
Stride = ( 0.0 , 0.44 , 1.0 )
Work = ( 3.0 , 2.48 , 20.0 )
Productivity = ( 3.0 , 2.48 , 20.0 )
Media = ( 11.0 , -0.71 , 47.0 )
Apple = ( 0.0 , 0.62 , 1.0 )
Communication = ( 0.0 , -0.21 , 18.0 )
Media = ( 0.0 , 1.67 , 0.0 )
Finance = ( 1.0 , -0.69 , 4.0 )
ZDNet = ( 1.0 , -0.69 , 4.0 )
Media = ( 0.0 , -0.38 , 4.0 )
Solution = ( 0.0 , -0.71 , 10.0 )
Collective = ( 0.0 , 1.53 , 13.0 )
Ventures = ( 0.0 , 1.39 , 8.0 )
finance = ( 69.0 , -0.69 , 81.0 )
Bank = ( 0.0 , 1.22 , 27.0 )
Market = ( 4.0 , -0.04 , 24.0 )
Botkeeper = ( 0.0 , 1.83 , 0.0 )
PayPal = ( 7.0 , -0.67 , 157.0 )
Group = ( 0.0 , 0.85 , 0.0 )
TransUnion = ( 6.0 , -0.63 , 119.0 )
Capital = ( 0.0 , -0.54 , 11.0 )
City= ( 0.0 , -0.72 , 1.0 )
Bond = ( 0.0 , -0.68 , 8.0 )
SoGal = ( 2.0 , -0.69 , 61.0 )
Lenovo = ( 33.0 , -0.55 , 21.0 )
Media = ( 58.0 , -0.47 , 259.0 )
CEO = ( 11.0 , 4.06 , 155.0 )
Principal = ( 0.0 , -0.72 , 4.0 )
Instructor = ( 0.0 , -0.72 , 4.0 )
Partners = ( 1.0 , -0.38 , 3.0 )
Professor = ( 1.0 , -0.71 , 18.0 )
talent = ( 35.0 , -0.62 , 168.0 )
Marketing = ( 65.0 , 1.14 , 321.0 )
Compliance = ( 0.0 , -0.73 , 3.0 )
Writer = ( 0.0 , -0.71 , 2.0 )
Head = ( 0.0 , 1.24 , 48.0 )
Director = ( 3.0 , -0.24 , 61.0 )
Editor = ( 0.0 , -0.72 , 1.0 )
Advisor = ( 0.0 , -0.38 , 4.0 )
Director = ( 0.0 , -0.71 , 3.0 )
Biodesign = ( 0.0 , -0.71 , 3.0 )
director = ( 1.0 , 0.64 , 7.0 )
Founder = ( 2.0 , 0.86 , 6.0 )
Director = ( 0.0 , -0.7 , 102.0 )
Partner = ( 0.0 , -0.7 , 102.0 )
founder = ( 0.0 , 0.44 , 1.0 )
Author = ( 5.0 , 0.48 , 18.0 )
Founder = ( 7.0 , 2.55 , 65.0 )
Creator = ( 3.0 , 2.48 , 20.0 )
Director = ( 11.0 , -0.71 , 47.0 )
Social = ( 0.0 , 0.62 , 1.0 )
head = ( 0.0 , -0.21 , 18.0 )
Marketing = ( 5.0 , -0.45 , 35.0 )
Founder = ( 14.0 , 2.06 , 78.0 )
Brand = ( 1.0 , -0.71 , 14.0 )
Business = ( 1.0 , -0.71 , 14.0 )
Speaker = ( 0.0 , -0.7 , 7.0 )
Entrepreneur = ( 0.0 , -0.7 , 7.0 )
Investor = ( 0.0 , -0.7 , 7.0 )
journalist = ( 1.0 , -0.69 , 4.0 )
columnist = ( 1.0 , -0.69 , 4.0 )
speaker = ( 59.0 , -0.44 , 263.0 )
author = ( 1.0 , -0.69 , 4.0 )
media = ( 1.0 , -0.69 , 4.0 )
Consultant = ( 0.0 , -0.71 , 10.0 )
founder = ( 2.0 , 0.42 , 50.0 )
Communication= ( 0.0 , 1.53 , 13.0 )
Academic = ( 0.0 , -0.4 , 1.0 )
Partner = ( 0.0 , 1.39 , 8.0 )
founder = ( 0.0 , 1.39 , 8.0 )
Economy = ( 69.0 , -0.69 , 81.0 )
Editor = ( 0.0 , 1.22 , 27.0 )
Adviser = ( 0.0 , 1.22 , 27.0 )
Author = ( 0.0 , 1.83 , 0.0 )
Learner = ( 2.0 , 0.4 , 40.0 )
creator = ( 2.0 , 0.4 , 40.0 )
Technology = ( 7.0 , -0.67 , 157.0 )
consultant = ( 1.0 , -0.67 , 7.0 )
consultant = ( 5.0 , 0.44 , 35.0 )
writer = ( 58.0 , -0.1 , 259.0 )
podcaster = ( 58.0 , -0.1 , 259.0 )
investor = ( 0.0 , -0.54 , 11.0 )
candidate = ( 25.0 , -0.58 , 332.0 )
founder= ( 0.0 , -0.72 , 1.0 )
partner = ( 0.0 , -0.68 , 8.0 )
Founder= ( 2.0 , -0.69 , 61.0 )
Brand = ( 33.0 , -0.55 , 21.0 )
writer = ( 38.0 , -0.48 , 100.0 )

# %%
combined =  [awareness ,clarity ,adaptability ,relationship ,communication ,ghostwrite ,branding ,fear ,softskill ,intelligence ,action ,
positivity ,
alignment ,
boundary ,
trust ,
progress ,
growth ,
email ,
business ,
write ,
productivity ,
hire ,
team ,
community ,
change ,
goals ,
success ,
development ,
brand ,
content ,
wellbeing ,
creativity ,
humanbehavior ,
intention ,
attention ,
consistency ,
discipline ,
wisdom ,
video ,
resilience ,
empathy ,
kindness ,
hope ,
optimism ,
possibility ,
focus ,
grit ,
growthmindset ,
help ,
vulnerability ,
promise ,
happyholiday ,
'acquire ',
'nir ',
'eyal ',
'palmer ',
'special ',
'lee ',
'africa ',
'naik ',
'innovator ',
'interview ',
'city ',
'move ',
'women ',
'citylife ',
'government ',
'juliet ',
'mutual ',
'year ',
'kleiner ',
'sogal ',
'magazine ',
'pocket ',
'trust ',
'professional ',
'volk ',
'follow ',
'newsletter ',
'personal ',
'podcast ',
'video ',
'ad ',
'expensive ',
'think ',
'Group ',
'School ',
'University ',
'Counsel ',
'University ',
'App ',
'Startup ',
'technology ',
'Read ',
'LinkedIn ',
'technology ',
'news ',
'Consulting ',
'Healthcare ',
'Biodesign ',
'Medical ',
'Partners ',
'Stride ',
'Work ',
'Productivity ',
'Media ',
'Apple ',
'Communication ',
'Media ',
'Finance ',
'ZDNet ',
'Media ',
'Solution ',
'Collective ',
'Ventures ',
'finance ',
'Bank ',
'Market ',
'Botkeeper ',
'PayPal ',
'Group ',
'TransUnion ',
'Capital ',
'City',
'Bond ',
'SoGal ',
'Lenovo ',
'Media ',
'CEO ',
'Principal ',
'Instructor ',
'Partners ',
'Professor ',
'talent ',
'Marketing ',
'Compliance ',
'Writer ',
'Head ',
'Director ',
'Editor ',
'Advisor ',
'Director ',
'Biodesign ',
'director ',
'Founder ',
'Director ',
'Partner ',
'founder ',
'Author ',
'Founder ',
'Creator ',
'Director ',
'Social ',
'head ',
'Marketing ',
'Founder ',
'Brand ',
'Business ',
'Speaker ',
'Entrepreneur ',
'Investor ',
'journalist ',
'columnist ',
'speaker ',
'author ',
'media ',
'Consultant ',
'founder ',
'Communication',
'Academic ',
'Partner ',
'founder ',
'Economy ',
'Editor ',
'Adviser ',
'Author ',
'Learner ',
'creator ',
'Technology ',
'consultant ',
'consultant ',
'writer ',
'podcaster ',
'investor ',
'candidate ',
'founder',
'partner ',
'Founder',
'Brand ',
'writer ']

# %% [markdown]
# ward演算法：兩個群體的最小方差，某一條線到每個點都是最短
# euclidean：歐幾里得距離

# %%
#  AgglomerativeClustering 類別是根據給定的簇數或者其他類似的指標來進行分群
clt = AgglomerativeClustering(linkage='ward', 
                              affinity='euclidean', 
                              n_clusters=2)
# 資料放入模型，取得每筆資料的群別代號
model = clt.fit(combined)
# model.labels_
# n_clusters = len(np.unique(model.labels_))
# print('Number of clusters:', n_clusters)
# Number of clusters: 6
# Out:
# c:\Users\cindy\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
#  AgglomerativeClustering 類別是根據給定的簇數或者其他類似的指標來進行分群
clt7 = AgglomerativeClustering(linkage='ward', 
                              affinity='euclidean', 
                              n_clusters=7)
# 資料放入模型，取得每筆資料的群別代號
model7 = clt7.fit(combined)
# model7.labels_
# n_clusters = len(np.unique(clusters))
# print('Number of clusters:', n_clusters)
# Number of clusters: 7
# Out:
# c:\Users\cindy\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
colors = ['darkseagreen', 'lightslategrey', 'cadetblue', 'rosybrown', 'goldenrod', 'peachpuff', 'black','salmon','green','blue']
# 將分群結果儲存在一個 Series 物件中
result = pd.DataFrame({'comment': combined[:, 0], 'reaction': combined[:, 1], 'follower': combined[:, 2], 'group': model.labels_})

# 繪製三維散點圖
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for i in range(2):
    ax.scatter(result.loc[result['group'] == i, 'comment'], result.loc[result['group'] == i, 'reaction'], result.loc[result['group'] == i, 'follower'], c=colors[i], label='cluster '+str(i+1))

ax.set_title('Hierarchical Clustering Result')
ax.set_xlabel('comment')
ax.set_ylabel('reaction')
ax.set_zlabel('follower')
ax.legend()
plt.show()

# %%
# 將分群結果儲存在一個 Series 物件中
result7 = pd.DataFrame({'comment': combined[:, 0], 'reaction': combined[:, 1], 'follower': combined[:, 2], 'group': model7.labels_})

# 繪製三維散點圖
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for i in range(7):
    ax.scatter(result7.loc[result7['group'] == i, 'comment'], result7.loc[result7['group'] == i, 'reaction'], result7.loc[result7['group'] == i, 'follower'], c=colors[i], label='cluster '+str(i+1))

ax.set_title('Hierarchical Clustering Result')
ax.set_xlabel('comment')
ax.set_ylabel('reaction')
ax.set_zlabel('follower')
ax.legend()
plt.show()

# %%
linked = linkage(combined, 'ward')

plt.figure(figsize=(20, 7))  
dendrogram(linked,  
            orientation='top')
plt.show()

# %%
# fcluster 函數會根據給定的距離閾值將數據分成簇
Z = linkage(combined, method='complete')
max_d = 1
clusters = fcluster(Z, max_d, criterion='distance')
# Number of clusters: 10

# %%
# 將分群結果儲存在一個 Series 物件中
result_ = pd.DataFrame({'comment': combined[:, 0], 'reaction': combined[:, 1], 'follower': combined[:, 2], 'group': clusters})

# 繪製三維散點圖
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for i in range(10):
    ax.scatter(result_.loc[result_['group'] == i, 'comment'], result_.loc[result_['group'] == i, 'reaction'], result_.loc[result_['group'] == i, 'follower'], c=colors[i], label='cluster '+str(i+1))

ax.set_title('Hierarchical Clustering Result')
ax.set_xlabel('comment')
ax.set_ylabel('reaction')
ax.set_zlabel('follower')
ax.legend()
plt.show()

# %% [markdown]
# 輪廓係數：該指標結合了簇內不相似度和簇間相似度，取值範圍為[-1, 1]。輪廓係數越接近1，表示聚類效果越好，不同簇之間的距離越大，同一簇內部數據點的距離越小

# %%
from sklearn.metrics import silhouette_score
score6 = silhouette_score(combined, model.labels_, metric='euclidean')
score7 = silhouette_score(combined, model7.labels_, metric='euclidean')
score10 = silhouette_score(combined, clusters, metric='euclidean')
print(score6, score7, score10)
# Out:
# 0.9109259266250711 0.6645369991902381 0.6829484071178967

# %% [markdown]
# Calinski-Harabasz指數：該指標也是一種聚類效果的評估指標，計算簇內的離差平方和與簇間離差平方和的比值。 Calinski-Harabasz指數越大，表示聚類效果越好

# %%
from sklearn.metrics import calinski_harabasz_score
six = calinski_harabasz_score(combined, model.labels_)
seven = calinski_harabasz_score(combined, model7.labels_)
ten =  calinski_harabasz_score(combined, clusters)
print(six, seven, ten)
# Out:
# 1521.6388214788196 5778.464522622066 542153.3151304248

# %% [markdown]
# 結論：分7群為最佳

# %%
grouped = result7.groupby('group')
for group_, data in grouped:
    print("Group ", group_+1)
    print("Mean values: ")
    print(data.mean())
    print("Standard deviations: ")
    print(data.std())
# Out:
# Group  1
# Mean values:
# comment      3.148571
# reaction     0.048381
# follower    17.518095
# group        0.000000
# dtype: float64
# Standard deviations:
# comment     6.039678
# reaction    0.685869
# follower    9.237453
# group       0.000000
# dtype: float64
# Group  2
# Mean values:
# comment      53.428571
# reaction     -0.428571
# follower    270.000000
# group         1.000000
# dtype: float64
# Standard deviations:
# comment     12.541360
# reaction     0.151595
# follower    27.380041
# group        0.000000
# dtype: float64
# Group  3
# Mean values:
# comment      86.244444
# reaction      6.772222
# follower    468.622222
# group         2.000000
# dtype: float64
# Standard deviations:
# comment      5.245739
# reaction     0.294694
# follower    20.902259
# group        0.000000
# dtype: float64
# Group  4
# Mean values:
# comment     46.155556
# reaction    -0.554444
# follower    95.377778
# group        3.000000
# dtype: float64
# Standard deviations:
# comment     24.019113
# reaction     0.177279
# follower    15.206395
# group        0.000000
# dtype: float64
# Group  5
# Mean values:
# comment      23.571429
# reaction      0.034286
# follower    163.000000
# group         4.000000
# dtype: float64
# Standard deviations:
# comment     14.316158
# reaction     1.775330
# follower     6.271629
# group        0.000000
# dtype: float64
# Group  6
# Mean values:
# comment     0.204312
# reaction   -0.161630
# follower    0.949710
# group       5.000000
# dtype: float64
# Standard deviations:
# comment     1.136516
# reaction    0.606313
# follower    1.623061
# group       0.000000
# dtype: float64
# Group  7
# Mean values:
# comment      7.081818
# reaction    -0.268636
# follower    55.336364
# group        6.000000
# dtype: float64
# Standard deviations:
# comment     5.164221
# reaction    0.513107
# follower    7.572227
# group       0.000000
# dtype: float64

# %%
new = result7.reset_index()

# %%
# 找出每個簇的變數是誰
variables = ['awareness ',
'clarity ',
'adaptability ',
'relationship ',
'communication ',
'ghostwrite ',
'branding ',
'fear ',
'softskill ',
'intelligence ',
'action ',
'positivity ',
'alignment ',
'boundary ',
'trust ',
'progress ',
'growth ',
'email ',
'business ',
'write ',
'productivity ',
'hire ',
'team ',
'community ',
'change ',
'goals ',
'success ',
'development ',
'brand ',
'content ',
'wellbeing ',
'creativity ',
'humanbehavior ',
'intention ',
'attention ',
'consistency ',
'discipline ',
'wisdom ',
'video ',
'resilience ',
'empathy ',
'kindness ',
'hope ',
'optimism ',
'possibility ',
'focus ',
'grit ',
'growthmindset ',
'help ',
'vulnerability ',
'promise ',
'happyholiday ',
'presence ',
'choice ',
'collaboration ',
'curiosity ',
'listen ',
'perspective ',
'position ',
'respect ',
'curious ',
'humility ',
'gratitude ',
'competence ',
'confidence ',
'candor ',
'veteransday ',
'veteran ',
'uncertainty ',
'positive ',
'influence ',
'passion ',
'podcast ',
'post ',
'hindsight ',
'foresight ',
'transformation ',
'inspiration ',
'mindset ',
'impact ',
'encouragement ',
'perfection ',
'time ',
'visualization ',
'work ',
'burnout ',
'stress ',
'softskill ',
'balance ',
'read ',
'write ',
'fiction ',
'human ',
'advice ',
'idea ',
'purpose ',
'talent ',
'energy ',
'guilt ',
'coronavirus ',
'lift ',
'mentalhealth ',
'simplicity ',
'badass ',
'understand ',
'unity ',
'humanity ',
'brand ',
'constraint ',
'reinvention ',
'motivation ',
'reframe ',
'gift ',
'support ',
'innovation ',
'performance ',
'business ',
'reflection ',
'meditation ',
'business ',
'charisma ',
'comparison ',
'unstuck ',
'future ',
'hr ',
'experience ',
'advisory ',
'consult ',
'generosity ',
'newyear ',
'resolution ',
'appreciation ',
'transition ',
'liminality ',
'Advisor ',
'Director ',
'Biodesign ',
'director ',
'Founder ',
'Director ',
'Partner ',
'founder ',
'Author ',
'Founder ',
'Creator ',
'Director ',
'Social ',
'head ',
'Marketing ',
'Founder ',
'Brand ',
'Business ',
'Speaker ',
'Entrepreneur ',
'Investor ',
'journalist ',
'columnist ',
'speaker ',
'author ',
'media ',
'Consultant ',
'founder ',
'Communication',
'Academic ',
'Partner ',
'founder ',
'Economy ',
'Editor ',
'Adviser ',
'Author ',
'Learner ',
'creator ',
'Technology ',
'consultant ',
'consultant ',
'writer ',
'podcaster ',
'investor ',
'candidate ',
'founder',
'partner ',
'Founder',
'Brand ',
'writer ']
wordlist = []
for i in range(7):
    wordlist.append([])
    for j in range(len(variables)):
        if new['group'][j] == i:
            wordlist[i].append(variables[j])
wordlist
# Out:
# [['communication ',
#   'content ',
#   'help ',
#   'time ',
#   'work ',
#   'innovation ',
#   'hr ',
#   'consult ',
#   'leadership ',
#   'communication ',
#   'hr ',
#   'leader ',
#   'innovation ',
#   'lobby ',
#   'content ',
#   'female ',
#   'create ',
#   'communication ',
#   'product ',
#   'management ',
#   'develop ',
#   'health ',
#   'clinical ',
#   'beth ',
#   'biotech ',
#   'venture ',
#   'help ',
#   'work ',
#   'client ',
#   'creative ',
#   'director ',
#   'say ',
#   'people ',
#   'word ',
#   'thing ',
#   'best ',
#   'way ',
#   'know ',
#   'week ',
#   'time ',
#   'university ',
#   'leadership ',
#   'economy ',
#   'reporter ',
#   'india ',
#   'software ',
#   'consult ',
#   'wealth ',
#   'investment ',
#   'engineer ',
#   'build ',
#   'every ',
#   'day ',
#   'psychology ',
#   'acquire ',
#   'nir ',
#   'eyal ',
#   'lee ',
#   'africa ',
#   'naik ',
#   'women ',
#   'sogal ',
#   'magazine ',
#   'pocket ',
#   'ad ',
#   'expensive ',
#   'think ',
#   'University ',
#   'University ',
#   'Work ',
#   'Productivity ',
#   'Communication ',
#   'Solution ',
#   'Collective ',
#   'Ventures ',
#   'Bank ',
#   'Market ',
#   'Capital ',
#   'Bond ',
#   'Lenovo ',
#   'Professor ',
#   'Marketing ',
#   'Editor ',
#   'director ',
#   'Partner ',
#   'Creator ',
#   'head ',
#   'Marketing ',
#   'Brand ',
#   'Business ',
#   'Speaker ',
#   'Entrepreneur ',
#   'Investor ',
#   'Consultant ',
#   'Communication',
#   'Partner ',
#   'Editor ',
#   'Adviser ',
#   'Learner ',
#   'creator ',
#   'consultant ',
#   'consultant ',
#   'investor ',
#   'partner ',
#   'Brand '],
#  ['Media ',
#   'Media ',
#   'Media ',
#   'Media ',
#   'speaker ',
#   'podcaster ',
#   'candidate '],
#  ['business ',
#   'brand ',
#   'brand ',
#   'business ',
#   'business ',
#   'market ',
#   'top ',
#   'business ',
#   'brand '],
#  ['writer ',
#   'new ',
#   'finance ',
#   'finance ',
#   'finance ',
#   'TransUnion ',
#   'Economy ',
#   'writer ',
#   'writer '],
#  ['talent ', 'talent ', 'App ', 'PayPal ', 'CEO ', 'talent ', 'Technology '],
#  ['awareness ',
#   'clarity ',
#   'adaptability ',
#   'relationship ',
#   'ghostwrite ',
#   'branding ',
#   'fear ',
#   'softskill ',
#   'intelligence ',
#   'action ',
#   'positivity ',
#   'alignment ',
#   'boundary ',
#   'trust ',
#   'progress ',
#   'growth ',
#   'email ',
#   'write ',
#   'productivity ',
#   'hire ',
#   'team ',
#   'community ',
#   'change ',
#   'goals ',
#   'success ',
#   'development ',
#   'wellbeing ',
#   'creativity ',
#   'humanbehavior ',
#   'intention ',
#   'attention ',
#   'consistency ',
#   'discipline ',
#   'wisdom ',
#   'resilience ',
#   'empathy ',
#   'kindness ',
#   'hope ',
#   'optimism ',
#   'possibility ',
#   'focus ',
#   'grit ',
#   'growthmindset ',
#   'vulnerability ',
#   'promise ',
#   'happyholiday ',
#   'presence ',
#   'choice ',
#   'collaboration ',
#   'curiosity ',
#   'listen ',
#   'perspective ',
#   'position ',
#   'respect ',
#   'curious ',
#   'humility ',
#   'gratitude ',
#   'competence ',
#   'confidence ',
#   'candor ',
#   'veteransday ',
#   'veteran ',
#   'uncertainty ',
#   'positive ',
#   'influence ',
#   'passion ',
#   'post ',
#   'hindsight ',
#   'foresight ',
#   'transformation ',
#   'inspiration ',
#   'mindset ',
#   'impact ',
#   'encouragement ',
#   'perfection ',
#   'visualization ',
#   'burnout ',
#   'stress ',
#   'softskill ',
#   'balance ',
#   'read ',
#   'write ',
#   'fiction ',
#   'human ',
#   'advice ',
#   'idea ',
#   'purpose ',
#   'energy ',
#   'guilt ',
#   'coronavirus ',
#   'lift ',
#   'mentalhealth ',
#   'simplicity ',
#   'badass ',
#   'understand ',
#   'unity ',
#   'humanity ',
#   'constraint ',
#   'reinvention ',
#   'motivation ',
#   'reframe ',
#   'gift ',
#   'support ',
#   'performance ',
#   'reflection ',
#   'meditation ',
#   'charisma ',
#   'comparison ',
#   'unstuck ',
#   'future ',
#   'experience ',
#   'advisory ',
#   'generosity ',
#   'newyear ',
#   'resolution ',
#   'appreciation ',
#   'transition ',
#   'liminality ',
#   'duality ',
#   'accountability ',
#   'travel ',
#   'culture ',
#   'vacation ',
#   'holiday ',
#   'sales ',
#   'intellgence ',
#   'service ',
#   'value ',
#   'perceptive ',
#   'communicate ',
#   'readinglist ',
#   'serve ',
#   'human ',
#   'ai ',
#   'teamwork ',
#   'open ',
#   'persuasion ',
#   'virtual ',
#   'career ',
#   'entrepreneur ',
#   'illuminate ',
#   'self ',
#   'book ',
#   'connect ',
#   'manage ',
#   'story ',
#   'social ',
#   'education ',
#   'internation ',
#   'school ',
#   'education ',
#   'career ',
#   'collaboration ',
#   'college ',
#   'trauma ',
#   'children ',
#   'media ',
#   'study ',
#   'liberal ',
#   'professor ',
#   'founder ',
#   'transport ',
#   'heavy ',
#   'experience ',
#   'operational ',
#   'specialist ',
#   'across ',
#   'specialize ',
#   'b2b ',
#   'technology ',
#   'care ',
#   'specialty ',
#   'healthcare ',
#   'technology ',
#   'phd ',
#   'care ',
#   'entrepreneur ',
#   'entrepreneur ',
#   'good ',
#   'life ',
#   'mosquito ',
#   'party ',
#   'want ',
#   'emotional ',
#   'intelligence ',
#   'example ',
#   'write ',
#   'world ',
#   'year ',
#   'burnout ',
#   'swordfish ',
#   'service ',
#   'social ',
#   'gap ',
#   'operation ',
#   'name ',
#   'thank ',
#   'digital ',
#   'executive ',
#   'track ',
#   'record ',
#   'base ',
#   'get ',
#   'author ',
#   'valley ',
#   'silicon ',
#   'kaizen ',
#   'search ',
#   'vikram ',
#   'like ',
#   'fintech ',
#   'series ',
#   'bank ',
#   'standard ',
#   'platform ',
#   'industry ',
#   'mobile ',
#   'design ',
#   'jody ',
#   'account ',
#   'firm ',
#   'role ',
#   'manager ',
#   'palmer ',
#   'special ',
#   'innovator ',
#   'interview ',
#   'citylife ',
#   'government ',
#   'juliet ',
#   'mutual ',
#   'year ',
#   'kleiner ',
#   'trust ',
#   'professional ',
#   'volk ',
#   'follow ',
#   'newsletter ',
#   'Group ',
#   'School ',
#   'Counsel ',
#   'technology ',
#   'Read ',
#   'LinkedIn ',
#   'technology ',
#   'news ',
#   'Healthcare ',
#   'Biodesign ',
#   'Medical ',
#   'Partners ',
#   'Stride ',
#   'Apple ',
#   'Finance ',
#   'ZDNet ',
#   'Botkeeper ',
#   'Group ',
#   'City',
#   'Principal ',
#   'Instructor ',
#   'Partners ',
#   'Compliance ',
#   'Writer ',
#   'Advisor ',
#   'Biodesign ',
#   'founder ',
#   'Author ',
#   'Social ',
#   'journalist ',
#   'columnist ',
#   'author ',
#   'media ',
#   'founder ',
#   'Academic ',
#   'founder ',
#   'Author ',
#   'founder'],
#  ['video ',
#   'podcast ',
#   'linkedin ',
#   'linkedin ',
#   'company ',
#   'city ',
#   'move ',
#   'personal ',
#   'podcast ',
#   'video ',
#   'Startup ',
#   'Consulting ',
#   'SoGal ',
#   'Head ',
#   'Director ',
#   'Director ',
#   'Founder ',
#   'Director ',
#   'Founder ',
#   'Director ',
#   'Founder ',
#   'Founder']]

# %%
# !python -m spacy download en_core_web_md
# Out:
# Collecting en-core-web-md==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.5.0/en_core_web_md-3.5.0-py3-none-any.whl (42.8 MB)
#      ---------------------------------------- 42.8/42.8 MB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from en-core-web-md==3.5.0) (3.5.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (8.1.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.24.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.25.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.10.7)
# Requirement already satisfied: jinja2 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (57.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from packaging>=20.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.4.7)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (4.5.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.26.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2022.9.24)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.0.4)
# Requirement already satisfied: colorama in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\cindy\appdata\local\programs\python\python38\lib\site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
import numpy as np
import spacy
from collections import Counter

# 讀取en_core_web_md模型
nlp = spacy.load("en_core_web_md")

# 建立分類標籤和對應的向量
labels = [
'Textile',
'Chemical',
'Food',
'Pharmaceutical',
'Electronics',
'Machinery',
'Automotive',
'Agriculture',
'Crop',
'Livestock',
'Fishing and aquaculture',
'Forestry and logging',
'Technology',
'Software',
'Information technology services',
'Internet services and applications',
'Telecommunications',
'Computer hardware',
'Semiconductors','electronics',
'Finance',
'Banking and credit',
'Investment banking and securities',
'Insurance',
'Asset management and investment',
'Payment and financial processing services',
'Retail',
'Brick-and-mortar retail stores',
'Online retail and e-commerce',
'Wholesale and distribution',
'Consumer goods manufacturing',
'Health care',
'Hospitals and clinics',
'Health care services and products',
'Medical equipment manufacturing',
'Biotechnology and pharmaceuticals',
'Health insurance',
'Energy and utilities',
'Oil and gas exploration and production',
'Renewable energy',
'Electric power generation and distribution',
'Water and waste management',
'Construction',
'Residential construction',
'Commercial and institutional construction',
'Infrastructure and civil engineering',
'Heavy construction and contracting',
'Transportation and logistics',
'Air transportation',
'Ground transportation',
'Shipping and freight',
'Warehousing and distribution',
'Media and entertainment',
'Film and television production and distribution',
'Music production and distribution',
'Publishing and journalism',
'Advertising and marketing','education','consulting']

industry = [nlp(label).vector for label in labels]

# 进行向量分类
for j in range(7):
    for word in wordlist[j]:
        word_vector = nlp(word).vector
        min_dist = float("inf")
        min_label = None
        for i, label in enumerate(labels):
            dist = np.linalg.norm(word_vector - industry[i])
            if dist < min_dist:
                min_dist = dist
                min_label = label
        print(word, "->", min_label)
# Out:
# communication  -> Telecommunications
# content  -> Advertising and marketing
# help  -> Health care services and products
# time  -> Shipping and freight
# work  -> consulting
# innovation  -> Biotechnology and pharmaceuticals
# hr  -> Brick-and-mortar retail stores
# consult  -> consulting
# leadership  -> Infrastructure and civil engineering
# communication  -> Telecommunications
# hr  -> Brick-and-mortar retail stores
# leader  -> Infrastructure and civil engineering
# innovation  -> Biotechnology and pharmaceuticals
# lobby  -> Pharmaceutical
# content  -> Advertising and marketing
# female  -> Publishing and journalism
# create  -> Advertising and marketing
# communication  -> Telecommunications
# product  -> Consumer goods manufacturing
# management  -> Asset management and investment
# develop  -> Biotechnology and pharmaceuticals
# health  -> Health care services and products
# clinical  -> Pharmaceutical
# beth  -> Publishing and journalism
# biotech  -> Pharmaceutical
# venture  -> Asset management and investment
# help  -> Health care services and products
# work  -> consulting
# client  -> Payment and financial processing services
# creative  -> Advertising and marketing
# director  -> Film and television production and distribution
# say  -> Livestock
# people  -> Livestock
# word  -> Computer hardware
# thing  -> Banking and credit
# best  -> Advertising and marketing
# way  -> Shipping and freight
# know  -> Livestock
# week  -> Livestock
# time  -> Shipping and freight
# university  -> Biotechnology and pharmaceuticals
# leadership  -> Infrastructure and civil engineering
# economy  -> Investment banking and securities
# reporter  -> Publishing and journalism
# india  -> Pharmaceutical
# software  -> Software
# consult  -> consulting
# wealth  -> Investment banking and securities
# investment  -> Asset management and investment
# engineer  -> Semiconductors
# build  -> Residential construction
# every  -> Payment and financial processing services
# day  -> Livestock
# psychology  -> Publishing and journalism
# acquire  -> Pharmaceutical
# nir  -> Pharmaceutical
# eyal  -> Pharmaceutical
# lee  -> Pharmaceutical
# africa  -> Machinery
# naik  -> Electronics
# women  -> Hospitals and clinics
# sogal  -> Pharmaceutical
# magazine  -> Publishing and journalism
# pocket  -> Computer hardware
# ad  -> Online retail and e-commerce
# expensive  -> Consumer goods manufacturing
# think  -> Livestock
# University  -> Technology
# University  -> Technology
# Work  -> Construction
# Productivity  -> Electric power generation and distribution
# Communication  -> Telecommunications
# Solution  -> Information technology services
# Collective  -> Music production and distribution
# Ventures  -> Media and entertainment
# Bank  -> Finance
# Market  -> Retail
# Capital  -> Asset management and investment
# Bond  -> Machinery
# Lenovo  -> Computer hardware
# Professor  -> Technology
# Marketing  -> Advertising and marketing
# Editor  -> Publishing and journalism
# director  -> Film and television production and distribution
# Partner  -> Automotive
# Creator  -> Computer hardware
# head  -> Forestry and logging
# Marketing  -> Advertising and marketing
# Brand  -> Automotive
# Business  -> Finance
# Speaker  -> Electronics
# Entrepreneur  -> Publishing and journalism
# Investor  -> Investment banking and securities
# Consultant  -> consulting
# Communication -> Telecommunications
# Partner  -> Automotive
# Editor  -> Publishing and journalism
# Adviser  -> Finance
# Learner  -> Information technology services
# creator  -> Publishing and journalism
# consultant  -> consulting
# consultant  -> consulting
# investor  -> Asset management and investment
# partner  -> consulting
# Brand  -> Automotive
# Media  -> Media and entertainment
# Media  -> Media and entertainment
# Media  -> Media and entertainment
# Media  -> Media and entertainment
# speaker  -> Semiconductors
# podcaster  -> Media and entertainment
# candidate  -> Pharmaceutical
# business  -> Investment banking and securities
# brand  -> Consumer goods manufacturing
# brand  -> Consumer goods manufacturing
# business  -> Investment banking and securities
# business  -> Investment banking and securities
# market  -> Consumer goods manufacturing
# top  -> Brick-and-mortar retail stores
# business  -> Investment banking and securities
# brand  -> Consumer goods manufacturing
# writer  -> Publishing and journalism
# new  -> Advertising and marketing
# finance  -> Investment banking and securities
# finance  -> Investment banking and securities
# finance  -> Investment banking and securities
# TransUnion  -> Agriculture
# Economy  -> Agriculture
# writer  -> Publishing and journalism
# writer  -> Publishing and journalism
# talent  -> Publishing and journalism
# talent  -> Publishing and journalism
# App  -> Software
# PayPal  -> Computer hardware
# CEO  -> Finance
# talent  -> Publishing and journalism
# Technology  -> Technology
# awareness  -> Advertising and marketing
# clarity  -> Publishing and journalism
# adaptability  -> Payment and financial processing services
# relationship  -> Publishing and journalism
# ghostwrite  -> Publishing and journalism
# branding  -> Advertising and marketing
# fear  -> Livestock
# softskill  -> Pharmaceutical
# intelligence  -> Telecommunications
# action  -> Commercial and institutional construction
# positivity  -> Heavy construction and contracting
# alignment  -> Commercial and institutional construction
# boundary  -> Forestry and logging
# trust  -> Banking and credit
# progress  -> Payment and financial processing services
# growth  -> Electric power generation and distribution
# email  -> Computer hardware
# write  -> Publishing and journalism
# productivity  -> Electric power generation and distribution
# hire  -> consulting
# team  -> consulting
# community  -> Commercial and institutional construction
# change  -> Payment and financial processing services
# goals  -> Asset management and investment
# success  -> Advertising and marketing
# development  -> Commercial and institutional construction
# wellbeing  -> Health care services and products
# creativity  -> Publishing and journalism
# humanbehavior  -> Pharmaceutical
# intention  -> Commercial and institutional construction
# attention  -> Publishing and journalism
# consistency  -> Wholesale and distribution
# discipline  -> Publishing and journalism
# wisdom  -> Publishing and journalism
# resilience  -> Fishing and aquaculture
# empathy  -> Publishing and journalism
# kindness  -> Publishing and journalism
# hope  -> Livestock
# optimism  -> Pharmaceutical
# possibility  -> Payment and financial processing services
# focus  -> Advertising and marketing
# grit  -> Machinery
# growthmindset  -> Pharmaceutical
# vulnerability  -> Payment and financial processing services
# promise  -> Pharmaceutical
# happyholiday  -> Pharmaceutical
# presence  -> Warehousing and distribution
# choice  -> Wholesale and distribution
# collaboration  -> Music production and distribution
# curiosity  -> Publishing and journalism
# listen  -> Computer hardware
# perspective  -> Publishing and journalism
# position  -> Commercial and institutional construction
# respect  -> Banking and credit
# curious  -> Publishing and journalism
# humility  -> Publishing and journalism
# gratitude  -> Publishing and journalism
# competence  -> Commercial and institutional construction
# confidence  -> Banking and credit
# candor  -> Publishing and journalism
# veteransday  -> Pharmaceutical
# veteran  -> Publishing and journalism
# uncertainty  -> Wholesale and distribution
# positive  -> Heavy construction and contracting
# influence  -> Electric power generation and distribution
# passion  -> Publishing and journalism
# post  -> Publishing and journalism
# hindsight  -> Pharmaceutical
# foresight  -> Payment and financial processing services
# transformation  -> Electric power generation and distribution
# inspiration  -> Publishing and journalism
# mindset  -> Publishing and journalism
# impact  -> Payment and financial processing services
# encouragement  -> Publishing and journalism
# perfection  -> Heavy construction and contracting
# visualization  -> Commercial and institutional construction
# burnout  -> Heavy construction and contracting
# stress  -> Water and waste management
# softskill  -> Pharmaceutical
# balance  -> Banking and credit
# read  -> Computer hardware
# write  -> Publishing and journalism
# fiction  -> Publishing and journalism
# human  -> Infrastructure and civil engineering
# advice  -> consulting
# idea  -> Computer hardware
# purpose  -> Payment and financial processing services
# energy  -> Renewable energy
# guilt  -> Publishing and journalism
# coronavirus  -> Pharmaceutical
# lift  -> Shipping and freight
# mentalhealth  -> Health care services and products
# simplicity  -> Wholesale and distribution
# badass  -> Computer hardware
# understand  -> Pharmaceutical
# unity  -> Electric power generation and distribution
# humanity  -> Publishing and journalism
# constraint  -> Commercial and institutional construction
# reinvention  -> Electric power generation and distribution
# motivation  -> Commercial and institutional construction
# reframe  -> Computer hardware
# gift  -> Textile
# support  -> Payment and financial processing services
# performance  -> Music production and distribution
# reflection  -> Commercial and institutional construction
# meditation  -> Commercial and institutional construction
# charisma  -> Textile
# comparison  -> Wholesale and distribution
# unstuck  -> Computer hardware
# future  -> Asset management and investment
# experience  -> Internet services and applications
# advisory  -> consulting
# generosity  -> Publishing and journalism
# newyear  -> Pharmaceutical
# resolution  -> Payment and financial processing services
# appreciation  -> Commercial and institutional construction
# transition  -> Commercial and institutional construction
# liminality  -> Payment and financial processing services
# duality  -> Publishing and journalism
# accountability  -> Payment and financial processing services
# travel  -> Shipping and freight
# culture  -> Fishing and aquaculture
# vacation  -> Residential construction
# holiday  -> Livestock
# sales  -> Consumer goods manufacturing
# intellgence  -> Pharmaceutical
# service  -> Information technology services
# value  -> Consumer goods manufacturing
# perceptive  -> Electric power generation and distribution
# communicate  -> Telecommunications
# readinglist  -> Pharmaceutical
# serve  -> Commercial and institutional construction
# human  -> Infrastructure and civil engineering
# ai  -> Livestock
# teamwork  -> Advertising and marketing
# open  -> Forestry and logging
# persuasion  -> Publishing and journalism
# virtual  -> Computer hardware
# career  -> Publishing and journalism
# entrepreneur  -> Publishing and journalism
# illuminate  -> Heavy construction and contracting
# self  -> Electric power generation and distribution
# book  -> Publishing and journalism
# connect  -> Telecommunications
# manage  -> Asset management and investment
# story  -> Publishing and journalism
# social  -> Advertising and marketing
# education  -> education
# internation  -> Commercial and institutional construction
# school  -> education
# education  -> education
# career  -> Publishing and journalism
# collaboration  -> Music production and distribution
# college  -> Hospitals and clinics
# trauma  -> Hospitals and clinics
# children  -> Hospitals and clinics
# media  -> Media and entertainment
# study  -> Biotechnology and pharmaceuticals
# liberal  -> Publishing and journalism
# professor  -> Publishing and journalism
# founder  -> Publishing and journalism
# transport  -> Ground transportation
# heavy  -> Heavy construction and contracting
# experience  -> Internet services and applications
# operational  -> Commercial and institutional construction
# specialist  -> consulting
# across  -> Warehousing and distribution
# specialize  -> Medical equipment manufacturing
# b2b  -> Pharmaceutical
# technology  -> Information technology services
# care  -> Health care
# specialty  -> Pharmaceutical
# healthcare  -> Health care services and products
# technology  -> Information technology services
# phd  -> Pharmaceutical
# care  -> Health care
# entrepreneur  -> Publishing and journalism
# entrepreneur  -> Publishing and journalism
# good  -> Livestock
# life  -> Publishing and journalism
# mosquito  -> Livestock
# party  -> Infrastructure and civil engineering
# want  -> Livestock
# emotional  -> Publishing and journalism
# intelligence  -> Telecommunications
# example  -> Wholesale and distribution
# write  -> Publishing and journalism
# world  -> Fishing and aquaculture
# year  -> Brick-and-mortar retail stores
# burnout  -> Heavy construction and contracting
# swordfish  -> Livestock
# service  -> Information technology services
# social  -> Advertising and marketing
# gap  -> Warehousing and distribution
# operation  -> Commercial and institutional construction
# name  -> Textile
# thank  -> Livestock
# digital  -> Semiconductors
# executive  -> Asset management and investment
# track  -> Semiconductors
# record  -> Music production and distribution
# base  -> Heavy construction and contracting
# get  -> Livestock
# author  -> Publishing and journalism
# valley  -> Forestry and logging
# silicon  -> Semiconductors
# kaizen  -> Publishing and journalism
# search  -> Internet services and applications
# vikram  -> Electronics
# like  -> Pharmaceutical
# fintech  -> Pharmaceutical
# series  -> Film and television production and distribution
# bank  -> Investment banking and securities
# standard  -> Electric power generation and distribution
# platform  -> Internet services and applications
# industry  -> Biotechnology and pharmaceuticals
# mobile  -> Semiconductors
# design  -> Commercial and institutional construction
# jody  -> Pharmaceutical
# account  -> Banking and credit
# firm  -> consulting
# role  -> Publishing and journalism
# manager  -> Asset management and investment
# palmer  -> Publishing and journalism
# special  -> Commercial and institutional construction
# innovator  -> Biotechnology and pharmaceuticals
# interview  -> Publishing and journalism
# citylife  -> Pharmaceutical
# government  -> Investment banking and securities
# juliet  -> Publishing and journalism
# mutual  -> Investment banking and securities
# year  -> Brick-and-mortar retail stores
# kleiner  -> Publishing and journalism
# trust  -> Banking and credit
# professional  -> consulting
# volk  -> Online retail and e-commerce
# follow  -> Forestry and logging
# newsletter  -> Publishing and journalism
# Group  -> Automotive
# School  -> Technology
# Counsel  -> Insurance
# technology  -> Information technology services
# Read  -> Electronics
# LinkedIn  -> Computer hardware
# technology  -> Information technology services
# news  -> Media and entertainment
# Healthcare  -> Health insurance
# Biodesign  -> Commercial and institutional construction
# Medical  -> Medical equipment manufacturing
# Partners  -> Asset management and investment
# Stride  -> Ground transportation
# Apple  -> Computer hardware
# Finance  -> Finance
# ZDNet  -> Pharmaceutical
# Botkeeper  -> Pharmaceutical
# Group  -> Automotive
# City -> Residential construction
# Principal  -> Publishing and journalism
# Instructor  -> Publishing and journalism
# Partners  -> Asset management and investment
# Compliance  -> Payment and financial processing services
# Writer  -> Publishing and journalism
# Advisor  -> Finance
# Biodesign  -> Commercial and institutional construction
# founder  -> Publishing and journalism
# Author  -> Publishing and journalism
# Social  -> Media and entertainment
# journalist  -> Publishing and journalism
# columnist  -> Publishing and journalism
# author  -> Publishing and journalism
# media  -> Media and entertainment
# founder  -> Publishing and journalism
# Academic  -> Publishing and journalism
# founder  -> Publishing and journalism
# Author  -> Publishing and journalism
# founder -> Publishing and journalism
# video  -> Computer hardware
# podcast  -> Media and entertainment
# linkedin  -> Wholesale and distribution
# linkedin  -> Wholesale and distribution
# company  -> Asset management and investment
# city  -> Residential construction
# move  -> Shipping and freight
# personal  -> Payment and financial processing services
# podcast  -> Media and entertainment
# video  -> Computer hardware
# Startup  -> Computer hardware
# Consulting  -> consulting
# SoGal  -> Pharmaceutical
# Head  -> Electronics
# Director  -> Technology
# Director  -> Technology
# Founder  -> Publishing and journalism
# Director  -> Technology
# Founder  -> Publishing and journalism
# Director  -> Technology
# Founder  -> Publishing and journalism
# Founder -> Publishing and journalism

# %% [markdown]
# 在自然語言處理領域中，cosine similarity比歐幾里得距離更常被使用。原因在於cosine similarity可以解決歐幾里得距離的一些限制，例如歐幾里得距離無法處理向量長度不同的情況。此外，cosine similarity通常被用來計算兩個文本的相似性，因為它能夠反應出兩個文本的方向和角度關係，而不僅僅是向量的大小。

# %%
import numpy as np
import spacy
from collections import Counter

# 讀取en_core_web_md模型
nlp = spacy.load("en_core_web_md")

# 建立分類標籤和對應的向量
labels = [
'Textile',
'Chemical',
'Food',
'Pharmaceutical',
'Electronics',
'Machinery',
'Automotive',
'Agriculture',
'Crop',
'Livestock',
'Fishing and aquaculture',
'Forestry and logging',
'Technology',
'Software',
'Information technology services',
'Internet services and applications',
'Telecommunications',
'Computer hardware',
'Semiconductors','electronics',
'Finance',
'Banking and credit',
'Investment banking and securities',
'Insurance',
'Asset management and investment',
'Payment and financial processing services',
'Retail',
'Brick-and-mortar retail stores',
'Online retail and e-commerce',
'Wholesale and distribution',
'Consumer goods manufacturing',
'Health care',
'Hospitals and clinics',
'Health care services and products',
'Medical equipment manufacturing',
'Biotechnology and pharmaceuticals',
'Health insurance',
'Energy and utilities',
'Oil and gas exploration and production',
'Renewable energy',
'Electric power generation and distribution',
'Water and waste management',
'Construction',
'Residential construction',
'Commercial and institutional construction',
'Infrastructure and civil engineering',
'Heavy construction and contracting',
'Transportation and logistics',
'Air transportation',
'Ground transportation',
'Shipping and freight',
'Warehousing and distribution',
'Media and entertainment',
'Film and television production and distribution',
'Music production and distribution',
'Publishing and journalism',
'Advertising and marketing','education','consulting']

industry = [nlp(label).vector for label in labels]

# 定義cosine similarity
def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

# 將每個單字分類至所屬的產業別
group_industries = []
for j in range(7):
    industries = []
    for word in wordlist[j]:
        word_vector = nlp(word).vector
        similarities = [cosine_similarity(word_vector, i) for i in industry]
        max_index = np.argmax(similarities)
        category = labels[max_index]
        industries.append(category)
    group_industries.append(industries)

# 計算每個j裡產業數量最多的產業和數量
for j in range(7):
    industries_count = Counter(group_industries[j])
    most_common_industry, count = industries_count.most_common(1)[0]
    print(f"Group {j}: {most_common_industry} ({count})")
# Out:
# C:\Users\cindy\AppData\Local\Temp\ipykernel_12268\4141745036.py:71: RuntimeWarning: invalid value encountered in scalar divide
#   return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))
# Group 0: consulting (12)
# Group 1: Media and entertainment (5)
# Group 2: Investment banking and securities (4)
# Group 3: Publishing and journalism (3)
# Group 4: Advertising and marketing (3)
# Group 5: Payment and financial processing services (27)
# Group 6: Finance (5)
